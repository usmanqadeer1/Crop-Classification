# %% [markdown]
# ## Authenticate to Colab, Cloud and GEE

# %%
from google.colab import drive
from google.colab import files
import sys

drive.mount('/content/gdrive/', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'Colab Notebooks/Classification/USA/Yolo_2/'
model_dir = base_dir + 'models/'
IMAGES_PATH = base_dir + '/' + 'Yolo_2016_16c/'

sys.path.append(base_dir)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## Import Libraries

# %%
import tensorflow as tf
from os import listdir
from os.path import isfile, join
from pprint import pprint
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns
print(tf.__version__)
import folium
print(folium.__version__)
# Out:
# 2.4.0
# 0.8.3

# %% [markdown]
# # Initialize global variables and functions

# %%
LABEL = 'landcover'


# landcovers = ['Rice', 'Alfalfa', 'Wheat', 'Sunflower', 'Safflower', 'Corn', 'YP', 'Tomatoes', 
#               'Grain and Hay', 'Grapes', 'Deciduous','Subtropical', 'Other Grass', 'Other Crops',
#               'Wetland', 'Fallowland', 'Buildup']
landcovers = ["Rice", "Safflower", "Corn", "Other Field crops", "Alfalfa", "Other Pasture", "Cucurbits", "Tomatoes", 
             "Other Truck Crops", "Almonds and pistachios", "Other Deciduous", "Subtropical", "Vineyards", "Other"]
nClasses = 16
r = 7

# %%
# new_labels = tf.constant([0,1,2,3,4,5,6,13,7,13,13,13,13,13,10,13,13,13,13,8,13,13,11,10,10,10,10,9,10,10,11,11,10,10,11,13,12,10,12,13,14,15,16], dtype = tf.int32,)
new_labels = tf.constant([0,4,13,3,1,2,13,6,7,8,8,8,8,8,10,3,8,8,8,13,3,8,11,10,9,9,10,12,10,10,11,11,10,10,11,8,5,10,5,8,13,13,13], dtype = tf.int32,)

new_labels
# Out:
# <tf.Tensor: shape=(43,), dtype=int32, numpy=
# array([ 0,  4, 13,  3,  1,  2, 13,  6,  7,  8,  8,  8,  8,  8, 10,  3,  8,
#         8,  8, 13,  3,  8, 11, 10,  9,  9, 10, 12, 10, 10, 11, 11, 10, 10,
#        11,  8,  5, 10,  5,  8, 13, 13, 13], dtype=int32)>

# %%
train_path = IMAGES_PATH + 'training_yolo_2016_16c'
validation_path = IMAGES_PATH + 'validation_yolo_2016_16c'
test_path = IMAGES_PATH + 'testing_yolo_2016_16c'

train_file_prefix = 'training_yolo_2016'
validation_file_prefix = 'validation_yolo_2016'
test_file_prefix = 'testing_yolo_2016'

def getDatasetPaths(path, image_file_prefix):
  filesList = listdir(path = path)
  exportFilesList = [s for s in filesList if image_file_prefix in s]
  imageFilesList = []

  for f in exportFilesList:
    if f.endswith('.tfrecord.gz'):
      imageFilesList.append(f)
    elif f.endswith('.json'):
      jsonFile = f

  datasetPaths = [path + '/' + f for f in imageFilesList] 
  return datasetPaths

train_dataset_paths = getDatasetPaths(train_path, train_file_prefix)
validation_dataset_paths = getDatasetPaths(validation_path, validation_file_prefix)
test_dataset_paths = getDatasetPaths(test_path, test_file_prefix)

# %%
# validation_dataset_paths

# %%
FEATURE_NAMES = []
bands =  ['B2', 'B3', 'B4', 'B5', 'B6','B7', 'NDVI', 'GNDVI', 'EVI', 'SAVI', 'BSI', 'NDWI', 'NDBI']
# bands =  ['NDVI', 'GNDVI', 'EVI', 'SAVI', 'BSI', 'NDWI', 'NDBI']

# bands =  ['B2', 'B3', 'B4', 'B5', 'B6','B7']
# bands =  ['B2', 'B3', 'B4', 'B5', 'B6','B7','NDVI','EVI']

time_stamps = 9
n_features = len(bands)
for i in range(time_stamps):
  if i > 0:
    s = [b + '_' + str(i) for b in bands]
  else:
    s = bands
  FEATURE_NAMES.extend(s)
FEATURE_NAMES.append(LABEL)
# for b in bands:
#   for i in range(time_stamps):
#     if i > 0:
#       s = b + '_' + str(i)
#     else:
#       s = b
#     FEATURE_NAMES.append(s)  
  
# FEATURE_NAMES.append(LABEL)
# FEATURE_NAMES

# %% [markdown]
# # Data preparation and pre-processing

# %%
# List of fixed-length features, all of which are float32.
from pprint import pprint
import numpy as np
# z = np.zeros(91,).tolist()

columns = [
  tf.io.FixedLenSequenceFeature(shape=[r,r], dtype=tf.float32, allow_missing = True) for k in FEATURE_NAMES
]
# Dictionary with names as keys, features as values.
from collections import OrderedDict 

# featuresDict = dict(zip(FEATURE_NAMES, columns))
featuresDict = OrderedDict(zip(FEATURE_NAMES, columns))

# pprint(featuresDict)

# %%
# Create a dataset from the TFRecord file in Cloud Storage.

depth = len(FEATURE_NAMES)-1
def toTuple(data, label):
  spectral = []
  for i in range(0, depth, n_features):
    band_values = []
    for f in FEATURE_NAMES[i:i+n_features]:
      if f.startswith('B'):
        band_values.append(tf.reshape(data[f],(r,r))/10000)
      else:   
        band_values.append(tf.reshape(data[f],(r,r)))
    spectral.append(band_values)
  
  spectral = tf.transpose(spectral, [2,3,0,1])
  label = tf.gather(new_labels, label)

  return spectral, label

def parse_tfrecord(example_proto):
  parsed_features = tf.io.parse_single_example(example_proto, featuresDict)
  labels = parsed_features.pop(LABEL)
  labels = tf.cast(labels, tf.int32)
  label = tf.math.argmax(tf.math.bincount(labels))
  return parsed_features, label

def getDataset(datasetPaths):
  dataset = tf.data.TFRecordDataset(datasetPaths, compression_type='GZIP')
  parsedDataset = dataset.map(parse_tfrecord, num_parallel_calls=5)
  inputDataset = parsedDataset.map(toTuple)
  return inputDataset

trainDataset = getDataset(train_dataset_paths)
validationDataset = getDataset(validation_dataset_paths)
testDataset = getDataset(test_dataset_paths)
alltestDataset = validationDataset.concatenate(testDataset)

# %%
for data, target in testDataset.take(5):
  print(data.shape)
  print(data[0][0])
  print(target)
# Out:
# (7, 7, 9, 13)
# tf.Tensor(
# [[ 8.41400027e-01  7.97699988e-01  6.84800029e-01  1.79310000e+00
#    8.94400001e-01  6.79899991e-01  4.47273910e-01  3.84205639e-01
#   -6.78274155e+00 -1.14228860e-01 -2.50444973e-05 -3.84205639e-01
#   -3.34399998e-01]
#  [ 8.41400027e-01  7.97699988e-01  6.84800029e-01  1.79310000e+00
#    8.94400001e-01  6.79899991e-01  4.47273910e-01  3.84205639e-01
#   -6.78274155e+00 -1.14228860e-01 -2.50444973e-05 -3.84205639e-01
#   -3.34399998e-01]
#  [ 1.12664998e+00  1.15139997e+00  1.28729999e+00  1.64279997e+00
#    1.93414998e+00  1.62995005e+00  1.21328264e-01  1.75858691e-01
activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_17 (Batc (None, 7, 7, 9, 13)       52
# _________________________________________________________________
# conv3d_14 (Conv3D)           (None, 7, 7, 9, 64)       22528
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 7, 7, 9, 64)       256
# _________________________________________________________________
# re_lu_14 (ReLU)              (None, 7, 7, 9, 64)       0
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 3, 3, 9, 64)       0
# _________________________________________________________________
# conv3d_15 (Conv3D)           (None, 3, 3, 9, 128)      221312
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 3, 3, 9, 128)      512
# _________________________________________________________________
# re_lu_15 (ReLU)              (None, 3, 3, 9, 128)      0
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 1, 1, 9, 128)      0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               147584
# _________________________________________________________________
# dense_14 (Dense)             (None, 14)                1806
# =================================================================
# Total params: 394,050
# Trainable params: 393,640
# Non-trainable params: 410
# _________________________________________________________________

# %% [markdown]
# ## Paper 3D CNN

# %%
pad = 'same'
l2 = 0
l1 = 0
f = [32, 64]
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape = ( r, r, time_stamps,n_features),),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Conv3D(filters = f[0], kernel_size = (3, 3, 3), padding = 'same'),
    tf.keras.layers.ReLU(),
    tf.keras.layers.AveragePooling3D(pool_size=(2, 2, 1)),

    tf.keras.layers.Conv3D(filters = f[1], kernel_size = (3, 3, 3), padding = 'same'),
    tf.keras.layers.ReLU(),
    tf.keras.layers.AveragePooling3D(pool_size=(2, 2, 1)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation = 'relu',  kernel_regularizer=tf.keras.regularizers.L1L2(l2 = l2, l1 = l1)),
    tf.keras.layers.Dense(14, activation = 'softmax')
])
model.summary()

# %%
pad = 'same'
l2 = 0
l1 = 0
f = [64, 128]
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape = ( r, r, time_stamps,n_features),),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Conv3D(filters = f[0], kernel_size = (3, 3, 3), padding = 'same'),
    tf.keras.layers.ReLU(),
    tf.keras.layers.AveragePooling3D(pool_size=(2, 2, 1)),

    tf.keras.layers.Conv3D(filters = f[1], kernel_size = (3, 3, 3), padding = 'same'),
    tf.keras.layers.ReLU(),
    tf.keras.layers.AveragePooling3D(pool_size=(2, 2, 1)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = 'relu',  kernel_regularizer=tf.keras.regularizers.L1L2(l2 = l2, l1 = l1)),
    tf.keras.layers.Dense(14, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_20 (Batc (None, 7, 7, 9, 13)       52
# _________________________________________________________________
# conv3d_16 (Conv3D)           (None, 7, 7, 9, 64)       22528
# _________________________________________________________________
# re_lu_16 (ReLU)              (None, 7, 7, 9, 64)       0
# _________________________________________________________________
# average_pooling3d_6 (Average (None, 3, 3, 9, 64)       0
# _________________________________________________________________
# conv3d_17 (Conv3D)           (None, 3, 3, 9, 128)      221312
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 3, 3, 9, 128)      0
# _________________________________________________________________
# average_pooling3d_7 (Average (None, 1, 1, 9, 128)      0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               147584
# _________________________________________________________________
# dense_16 (Dense)             (None, 14)                1806
# =================================================================
# Total params: 393,282
# Trainable params: 393,256
# Non-trainable params: 26
# _________________________________________________________________

# %%
pad = 'same'
l2 = 0
l1 = 0
f = [32, 64]
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape = ( r, r, time_stamps,n_features),),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Conv3D(filters = f[0], kernel_size = (3, 3, 3), padding = 'same'),
    tf.keras.layers.ReLU(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling3D(pool_size=(2, 2, 1)),

    tf.keras.layers.Conv3D(filters = f[1], kernel_size = (3, 3, 3), padding = 'same'),
    tf.keras.layers.ReLU(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling3D(pool_size=(2, 2, 1)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation = 'relu',  kernel_regularizer=tf.keras.regularizers.L1L2(l2 = l2, l1 = l1)),
    tf.keras.layers.Dense(14, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_21 (Batc (None, 7, 7, 9, 13)       52
# _________________________________________________________________
# conv3d_18 (Conv3D)           (None, 7, 7, 9, 32)       11264
# _________________________________________________________________
# re_lu_18 (ReLU)              (None, 7, 7, 9, 32)       0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 7, 7, 9, 32)       128
# _________________________________________________________________
# average_pooling3d_8 (Average (None, 3, 3, 9, 32)       0
# _________________________________________________________________
# conv3d_19 (Conv3D)           (None, 3, 3, 9, 64)       55360
# _________________________________________________________________
# re_lu_19 (ReLU)              (None, 3, 3, 9, 64)       0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 3, 3, 9, 64)       256
# _________________________________________________________________
# average_pooling3d_9 (Average (None, 1, 1, 9, 64)       0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                36928
# _________________________________________________________________
# dense_18 (Dense)             (None, 14)                910
# =================================================================
# Total params: 104,898
# Trainable params: 104,680
# Non-trainable params: 218
# _________________________________________________________________

# %% [markdown]
# ## Ensemble

# %%
def unit(f = [32, 64]):
  model = tf.keras.Sequential([
    tf.keras.layers.Input(shape = ( r, r, time_stamps,n_features),),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Conv3D(filters = f[0], kernel_size = (3, 3, 3), padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 1)),

    tf.keras.layers.Conv3D(filters = f[1], kernel_size = (3, 3, 3), padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 1)),
    

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation = 'relu'),
  ])
  return model

def model():
  input = tf.keras.layers.Input(shape = ( r, r, time_stamps, n_features))
  x = tf.keras.layers.BatchNormalization()(input)
  unit1 = unit([32, 64])(x)
  unit2 = unit([48, 96])(x)
  unit3 = unit([64, 128])(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Concatenate()([unit1, unit2, unit3])
  x = tf.keras.layers.Dropout(0.2)(x)
  x = tf.keras.layers.Dense(14, activation = 'softmax')(x)
  model = tf.keras.Model(input, x)
  return model

model = model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 7, 7, 9, 13) 0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 7, 7, 9, 13)  52          input_3[0][0]
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 128)          140916      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 128)          252756      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# sequential_4 (Sequential)       (None, 128)          392244      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 384)          0           sequential_2[0][0]
#                                                                  sequential_3[0][0]
#                                                                  sequential_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 384)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 14)           5390        dropout_3[0][0]
# ==================================================================================================
# Total params: 791,358
# Trainable params: 790,390
# Non-trainable params: 968
# __________________________________________________________________________________________________

# %% [markdown]
# # Conv3D w/ LSTM

# %%
input = tf.keras.layers.Input((r,r,time_stamps,n_features))
x = tf.keras.layers.BatchNormalization()(input)

x = tf.keras.layers.Conv3D(filters = 64, kernel_size = (3, 3, 3), padding = 'same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.MaxPool3D((2,2,1))(x)

x = tf.keras.layers.Conv3D(filters = 128, kernel_size = (3, 3, 3), padding = 'same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.MaxPool3D((2,2,1))(x)
x = tf.squeeze(tf.squeeze(x, axis = 1), axis = 1)
x = tf.keras.layers.LSTM(units = 32, return_sequences = True, recurrent_dropout = 0.2)(x)

# x = tf.keras.layers.Conv1D(128, kernel_size = 3, padding = 'same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.ReLU()(x)
# x = tf.keras.layers.MaxPooling1D()(x)
# x = tf.keras.layers.Conv1D(256, kernel_size = 3, padding = 'same')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.ReLU()(x)
# x = tf.keras.layers.MaxPooling1D()(x)

x = tf.keras.layers.Flatten()(x)
# x = tf.keras.layers.Dropout(0.2)(x)
# x = tf.keras.layers.Dense(128)(x)
x = tf.keras.layers.Dense(14, activation = 'softmax')(x)
model = tf.keras.Model(input, x)
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 7, 7, 9, 13)]     0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 7, 9, 13)       52
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 7, 9, 64)       22528
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 7, 7, 9, 64)       256
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 7, 7, 9, 64)       0
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 3, 3, 9, 64)       0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 3, 3, 9, 128)      221312
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3, 3, 9, 128)      512
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 3, 3, 9, 128)      0
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 1, 1, 9, 128)      0
# _________________________________________________________________
# tf.compat.v1.squeeze_4 (TFOp (None, 1, 9, 128)         0
# _________________________________________________________________
# tf.compat.v1.squeeze_5 (TFOp (None, 9, 128)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 9, 32)             20608
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 288)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 14)                4046
# =================================================================
# Total params: 269,314
# Trainable params: 268,904
# Non-trainable params: 410
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
batch_size = 128
num_epochs = 30

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.9, patience=3, min_lr=1e-10, min_delta=0.003, verbose = 1)
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    model_dir + '/model3_paper_conv3d_2016_7x7x9x13_13c', monitor='val_accuracy', verbose=0, save_best_only=True,
    save_weights_only=False, mode='auto', save_freq='epoch',
    options=None
)

optim = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='sparse_categorical_crossentropy', optimizer=optim, metrics=['accuracy']) 

history = model.fit(trainDataset.batch(batch_size), 
                    batch_size=batch_size, 
                    epochs=num_epochs, verbose=1,
                    validation_data = alltestDataset.batch(batch_size),
                    callbacks = [reduce_lr, 
                                 model_checkpoint_callback
                                 ]
)
# Out:
# Epoch 1/30
# 1217/1217 [==============================] - 111s 91ms/step - loss: 0.5234 - accuracy: 0.8418 - val_loss: 0.4971 - val_accuracy: 0.8749
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Classification/USA/Yolo_2/models/model3_paper_conv3d_2016_7x7x9x13_13c/assets
# Epoch 2/30
# 1217/1217 [==============================] - 109s 90ms/step - loss: 0.1980 - accuracy: 0.9399 - val_loss: 0.5533 - val_accuracy: 0.8748
# Epoch 3/30
# 1217/1217 [==============================] - 109s 89ms/step - loss: 0.1433 - accuracy: 0.9564 - val_loss: 0.5795 - val_accuracy: 0.8759
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Classification/USA/Yolo_2/models/model3_paper_conv3d_2016_7x7x9x13_13c/assets
# Epoch 4/30
# 1217/1217 [==============================] - 111s 91ms/step - loss: 0.1138 - accuracy: 0.9655 - val_loss: 0.6341 - val_accuracy: 0.8720
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
# Epoch 5/30
# 1217/1217 [==============================] - 111s 91ms/step - loss: 0.0910 - accuracy: 0.9721 - val_loss: 0.6964 - val_accuracy: 0.8700
# Epoch 6/30
# 1217/1217 [==============================] - 111s 91ms/step - loss: 0.0783 - accuracy: 0.9760 - val_loss: 0.7237 - val_accuracy: 0.8707
# Epoch 7/30
# 1217/1217 [==============================] - 111s 91ms/step - loss: 0.0669 - accuracy: 0.9790 - val_loss: 0.7945 - val_accuracy: 0.8743
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
# Epoch 8/30
# 1217/1217 [==============================] - 112s 92ms/step - loss: 0.0561 - accuracy: 0.9821 - val_loss: 0.7993 - val_accuracy: 0.8755
# Epoch 9/30
# 1217/1217 [==============================] - 111s 92ms/step - loss: 0.0501 - accuracy: 0.9840 - val_loss: 0.8116 - val_accuracy: 0.8770
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Classification/USA/Yolo_2/models/model3_paper_conv3d_2016_7x7x9x13_13c/assets
# Epoch 10/30
# 1217/1217 [==============================] - 112s 92ms/step - loss: 0.0453 - accuracy: 0.9858 - val_loss: 0.8865 - val_accuracy: 0.8742

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_20 (Batc (None, 7, 7, 9, 13)       52
# _________________________________________________________________
# conv3d_16 (Conv3D)           (None, 7, 7, 9, 64)       22528
# _________________________________________________________________
# re_lu_16 (ReLU)              (None, 7, 7, 9, 64)       0
# _________________________________________________________________
# average_pooling3d_6 (Average (None, 3, 3, 9, 64)       0
# _________________________________________________________________
# conv3d_17 (Conv3D)           (None, 3, 3, 9, 128)      221312
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 3, 3, 9, 128)      0
# _________________________________________________________________
# average_pooling3d_7 (Average (None, 1, 1, 9, 128)      0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               147584
# _________________________________________________________________
# dense_16 (Dense)             (None, 14)                1806
# =================================================================
# Total params: 393,282
# Trainable params: 393,256
# Non-trainable params: 26
# _________________________________________________________________

# %%
# model = tf.keras.models.load_model(model_dir + '/model3_conv3d_2016_7x7x9x13')
# model = tf.keras.models.load_model(model_dir + '/model4_conv3d_2016_7x7x9x6')
# model = tf.keras.models.load_model(model_dir + '/model5_conv3d_2016_7x7x9x6_43c')
# model = tf.keras.models.load_model(model_dir + '/model6_conv3d_2016_7x7x9x6_13c')
# model = tf.keras.models.load_model(model_dir + '/model7_conv3d_2016_7x7x9x13_13c')
#------------------------------------------------------------------------------------#
# model = tf.keras.models.load_model(model_dir + '/model8_conv3d_2016_7x7x9x13_13c') #89.27%
# model = tf.keras.models.load_model(model_dir + '/model_paper_conv3d_2016_7x7x9x13_13c') #87.59
model = tf.keras.models.load_model(model_dir + '/model2_paper_conv3d_2016_7x7x9x13_13c') #88.01

# model = tf.keras.models.load_model(model_dir + '/model9_conv3d_2016_7x7x9x13_13c') #ensemble #89.78%
# model = tf.keras.models.load_model(model_dir + '/model10_conv3d_2016_7x7x9x13_13c') # 89.70%
# model = tf.keras.models.load_model(model_dir + '/model11_conv3d_2016_7x7x9x13_13c') #89.60
# model = tf.keras.models.load_model(model_dir + '/model_res_conv3d_2016_7x7x9x13_13c') #
# model = tf.keras.models.load_model(model_dir + '/model_convlstm_conv3d_2016_7x7x9x13_13c') #90.23

# %%
 model.evaluate(alltestDataset.batch(1000))
# Out:
# 128/128 [==============================] - 48s 370ms/step - loss: 0.8016 - accuracy: 0.8801
# [0.8015537261962891, 0.8801390528678894]

# %%
model.evaluate(testDataset.batch(1000))
# Out:
# 69/69 [==============================] - 34s 483ms/step - loss: 1.0224 - accuracy: 0.8911
# [1.022383689880371, 0.8911066651344299]

# %% [markdown]
# # Analysis

# %%
y_pred = np.argmax(model.predict(alltestDataset.batch(10000)),axis = 1)
y_true = tf.concat([y for x, y in alltestDataset], axis=0)
# f1_score(y_true.numpy(), y_pred, average = 'weighted')
cf = tf.math.confusion_matrix(labels=y_true, predictions=y_pred).numpy()

print(cf)
s = np.sum(cf, axis = 1)

# cf1 = pd.DataFrame(cf/(s.reshape(nClasses-1, 1)), columns=landcovers[:-1], index = landcovers[:-1])
cf1 = pd.DataFrame(cf/(s.reshape(14, 1))*100, columns=landcovers, index = landcovers)
# Out:
# [[13785     7    10    14     9    11    27   169     9    33    22    10
#       7   268]
#  [    3  2800   165    69   123     1    37    14     0     2     3     0
#       7   105]
#  [  105    58  1626   267    59     8    68   278    18     3     3     0
#      19   129]
#  [  103   282    83  5948    74    16   104   536    19    15     7     1
#       1   435]
#  [    3    61    16    15  9314   212     4    26    25    11    22     1
#      13   299]
#  [    8     0     4    14   396  3703     5     0     9     9     9     1
#       3   612]
#  [    1     4    44    46    54    14  1430   203    70     4     9     0
#      11   188]
#  [    7    21    97   136    40    10    56  9347    24    14     4     0
#       9   241]
#  [    5    40    37    52    82     8   274   192   704    48    18     5
#      30   387]
#  [    8    10     3    13    39    10     6    19    52  8876    44    64
#      53  1357]
#  [   13     5     6    12    49    14     5     6    44   159  5143    20
#      86   530]
#  [    0     0     0     0     2     2     0     0     4   106    35   908
#       4    48]
#  [    2     7     3     0    18     2     0     3     6    68    52     5
#    5420   398]
#  [  321   226    72   260   550   789    71   113   190   799   174    31
#     245 43432]]

# %%
from sklearn.metrics import f1_score
f1_score(y_true.numpy(), y_pred, average = 'weighted')
# Out:
# 0.8782475908309044

# %%
plt.figure(figsize = (35,15))
sns.set(font_scale=2) 
sns.heatmap(cf1, annot=True, annot_kws={"size": 25},fmt = '.0f')

# %%
np.bincount(y_true)
# Out:
# array([6050, 4773, 3974, 3336, 1308, 1480, 1477, 4710, 1966, 2606, 8230,
#         569, 2436, 2095, 4852, 3623, 6077])

# %%
(np.sum(cf, axis = 1)/np.sum(cf))*100
# Out:
# array([12.21805063,  2.96395154,  1.70269557,  5.90737101,  7.69806119,
#         3.42738979,  1.71002845,  7.76699029,  1.40644707,  8.61173848,
#         3.73097117,  0.79195143,  4.95409615, 37.11025724])
