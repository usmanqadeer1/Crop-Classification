# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import ee 
# from ee_plugin import Map 
import geemap
import pprint as pprint
from datetime import datetime

# %%
try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()

# %% [markdown]
# # Import features collections and data

# %%
Map = geemap.Map(center=(40, -100), zoom=4)
geometry = ee.FeatureCollection('users/2014ee070/ImperialCountyBoundary')
data = ee.FeatureCollection('users/2014ee070/imperialCDWR2016')
imperial = geometry

# %% [markdown]
# # Defining inputs

# %%
start_date = '2016-01-01'
end_date = '2016-12-30'
nClasses = 28
num_classes = 28

# %%
classes = ["Citrus",  "Dates",  "Miscellaneous Subtropical Fruits",  "Olives",  "Miscellaneous Deciduous",  
           "Corn, Sorghum and Sudan",  "Miscellaneous Field Crops",  "Sunflowers",  
           "Miscellaneous Grain and Hay",  "Wheat",  "Managed Wetland",  "Alfalfa and Alfalfa Mixtures",  
           "Miscellaneous Grasses",  "Mixed Pasture",  "Carrots",  "Cole Crops",  
           "Flowers, Nursery and Christmas Tree Farms",  "Greenhouse",  "Lettuce/Leafy Greens",
           "Melons, Squash and Cucumbers",  "Miscellaneous Truck Crops",  "Onions and Garlic",  
           "Peppers",  "Potatoes and Sweet Potatoes",  "Tomatoes",  "Urban",  "Idle",  "Young Perennials"]

# %% [markdown]
# # Defining Functions

# %%
def maskS2sr(image):
    qa = image.select('QA60');
    cloudBitMask = 1 << 10;
    cirrusBitMask = 1 << 11;
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(
             qa.bitwiseAnd(cirrusBitMask).eq(0));
    # Return the masked image, scaled to reflectance, without the QA bands.
    return image.updateMask(mask) \
        .select(['B2', 'B3', 'B4', 'B8', 'B11', 'B12'])\
        .copyProperties(image, ["system:time_start"]);


def addNDVI(image):
    ndvi = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    return image.addBands(ndvi)


def addGNDVI(image):
    gndvi = image.normalizedDifference(['B8', 'B3']).rename('GNDVI')
    return image.addBands(gndvi)


def addEVI(image):
    evi = image.expression("2.5 * ((nir-red)/(nir + 6*red -7.5*blue + 1))",
    {
    'nir' : image.select("B8"),
    'red' : image.select("B4"),
    'blue': image.select("B2")
    }).rename('EVI')
    return image.addBands(evi)


def addSAVI(image):
    savi = image.expression("1.5*(red-green)/(red+green+0.5)",
    {
    'red' : image.select("B4"),
    'green': image.select("B3")
    }).rename('SAVI')
    return image.addBands(savi)


def addNDWI(image):
    ndwi = image.normalizedDifference(['B3', 'B8']).rename('NDWI')
    return image.addBands(ndwi)

def addNDBI(image):
    ndbi = image.normalizedDifference(['B11', 'B8']).rename('NDBI')
    return image.addBands(ndbi)

def addBSI(image):
    bsi = image.expression("((swir + red) - (nir + blue))/((swir + red) + (nir + blue))",
    {
    'blue' : image.select("B2"),
    'red' : image.select("B4"),
    'nir' : image.select("B8"),
    'swir': image.select("B11")
    }).rename('BSI')
    return image.addBands(bsi) 

def ymdList(imgcol):
    def iter_func(image, newlist):
        date = ee.String(image.date().format("YYYY-MM-dd"))
        newlist = ee.List(newlist)
        return ee.List(newlist.add(date).sort())

    return imgcol.iterate(iter_func, ee.List([]))

def temporalCollection(collection, start, count, interval, units):
    sequence = ee.List.sequence(0, ee.Number(count).subtract(1))
    originalStartDate = ee.Date(start)

    def func_aoa(i):
        startDate = originalStartDate.advance(ee.Number(interval).multiply(i), units)
        endDate = originalStartDate.advance(ee.Number(interval).multiply(ee.Number(i).add(1)), units)
        resultImage = collection.filterDate(startDate, endDate).median() \
                          .set('system:time_start', startDate.millis()) \
                          .set('system:time_end', endDate.millis())
        return resultImage

    return ee.ImageCollection(sequence.map(func_aoa))

# %% [markdown]
# # Preprocessing Imagery Landsat 8

# %%
Map.centerObject(geometry)
s2Collection = ee.ImageCollection("COPERNICUS/S2") \
                  .filterDate(start_date, end_date) \
                  .filterBounds(geometry) \
                  .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 10)) \
                  .map(maskS2sr) \
                  .map(addNDVI).map(addGNDVI).map(addEVI).map(addSAVI).map(addBSI).map(addNDWI).map(addNDBI) \
                  .sort('system:time_start', True);
print("images In collection",s2Collection.size().getInfo())
s2Collection = temporalCollection(s2Collection, start_date, 12, 30, 'day')
# Out:
# images In collection 79

# %% [markdown]
# ## Displaying all images selected each month

# %%
# # #*************** Get 12 images from s2 ***********************#

s2ImagesList = s2Collection.toList(s2Collection.size())
finalImage = ee.Image(s2ImagesList.get(0)).clip(geometry)
ts = ee.Image(s2ImagesList.get(0)).get('system:time_start').getInfo()
print(datetime.utcfromtimestamp(ts/1000).strftime('%Y-%m-%d %H:%M:%S'))

# Map.addLayer(finalImage, {'bands': ['B4', 'B3', 'B2'], 'min':0,'max': 3000}, 's2-1')

n = 1
i = 1
while i < 12:
    n = n + 1
    current = ee.Image(s2ImagesList.get(i)).clip(geometry)

    ts = current.get('system:time_start').getInfo()
    print(datetime.utcfromtimestamp(ts/1000).strftime('%Y-%m-%d %H:%M:%S'))
    
    finalImage = finalImage.addBands(current)
    # Map.addLayer(current, {'bands': ['B4', 'B3', 'B2'], 'min':0,'max': 3000}, 's2-'+n)
    i = i + 1

image = finalImage.clip(geometry).toFloat()
featuresNames = image.bandNames()
print('All features', featuresNames.getInfo())
# Out:
# 2016-01-01 00:00:00
# 2016-01-31 00:00:00
# 2016-03-01 00:00:00
# 2016-03-31 00:00:00
# 2016-04-30 00:00:00
# 2016-05-30 00:00:00
# 2016-06-29 00:00:00
# 2016-07-29 00:00:00
# 2016-08-28 00:00:00
# 2016-09-27 00:00:00
# 2016-10-27 00:00:00
# 2016-11-26 00:00:00
# All features ['B2', 'B3', 'B4', 'B8', 'B11', 'B12', 'NDVI', 'GNDVI', 'EVI', 'SAVI', 'BSI', 'NDWI', 'NDBI', 'B2_1', 'B3_1', 'B4_1', 'B8_1', 'B11_1', 'B12_1', 'NDVI_1', 'GNDVI_1', 'EVI_1', 'SAVI_1', 'BSI_1', 'NDWI_1', 'NDBI_1', 'B2_2', 'B3_2', 'B4_2', 'B8_2', 'B11_2', 'B12_2', 'NDVI_2', 'GNDVI_2', 'EVI_2', 'SAVI_2', 'BSI_2', 'NDWI_2', 'NDBI_2', 'B2_3', 'B3_3', 'B4_3', 'B8_3', 'B11_3', 'B12_3', 'NDVI_3', 'GNDVI_3', 'EVI_3', 'SAVI_3', 'BSI_3', 'NDWI_3', 'NDBI_3', 'B2_4', 'B3_4', 'B4_4', 'B8_4', 'B11_4', 'B12_4', 'NDVI_4', 'GNDVI_4', 'EVI_4', 'SAVI_4', 'BSI_4', 'NDWI_4', 'NDBI_4', 'B2_5', 'B3_5', 'B4_5', 'B8_5', 'B11_5', 'B12_5', 'NDVI_5', 'GNDVI_5', 'EVI_5', 'SAVI_5', 'BSI_5', 'NDWI_5', 'NDBI_5', 'B2_6', 'B3_6', 'B4_6', 'B8_6', 'B11_6', 'B12_6', 'NDVI_6', 'GNDVI_6', 'EVI_6', 'SAVI_6', 'BSI_6', 'NDWI_6', 'NDBI_6', 'B2_7', 'B3_7', 'B4_7', 'B8_7', 'B11_7', 'B12_7', 'NDVI_7', 'GNDVI_7', 'EVI_7', 'SAVI_7', 'BSI_7', 'NDWI_7', 'NDBI_7', 'B2_8', 'B3_8', 'B4_8', 'B8_8', 'B11_8', 'B12_8', 'NDVI_8', 'GNDVI_8', 'EVI_8', 'SAVI_8', 'BSI_8', 'NDWI_8', 'NDBI_8', 'B2_9', 'B3_9', 'B4_9', 'B8_9', 'B11_9', 'B12_9', 'NDVI_9', 'GNDVI_9', 'EVI_9', 'SAVI_9', 'BSI_9', 'NDWI_9', 'NDBI_9', 'B2_10', 'B3_10', 'B4_10', 'B8_10', 'B11_10', 'B12_10', 'NDVI_10', 'GNDVI_10', 'EVI_10', 'SAVI_10', 'BSI_10', 'NDWI_10', 'NDBI_10', 'B2_11', 'B3_11', 'B4_11', 'B8_11', 'B11_11', 'B12_11', 'NDVI_11', 'GNDVI_11', 'EVI_11', 'SAVI_11', 'BSI_11', 'NDWI_11', 'NDBI_11']

# %% [markdown]
# # FIltering and remapping CRS data labels

# %%
#************* remapping crops to major crops *****************#

classSizes = {}
for i in range(0, nClasses, 1):
    classSizes[classes[i]] = data.filter(ee.Filter.eq('landover', i)).size().getInfo()

pprint.pprint(classes)
pprint.pprint(classSizes)
# Out:
# ['Citrus',
#  'Dates',
#  'Miscellaneous Subtropical Fruits',
#  'Olives',
#  'Miscellaneous Deciduous',
#  'Corn, Sorghum and Sudan',
#  'Miscellaneous Field Crops',
#  'Sunflowers',
#  'Miscellaneous Grain and Hay',
#  'Wheat',
#  'Managed Wetland',
#  'Alfalfa and Alfalfa Mixtures',
#  'Miscellaneous Grasses',
#  'Mixed Pasture',
#  'Carrots',
#  'Cole Crops',
#  'Flowers, Nursery and Christmas Tree Farms',
#  'Greenhouse',
#  'Lettuce/Leafy Greens',
#  'Melons, Squash and Cucumbers',
#  'Miscellaneous Truck Crops',
#  'Onions and Garlic',
#  'Peppers',
#  'Potatoes and Sweet Potatoes',
#  'Tomatoes',
#  'Urban',
#  'Idle',
#  'Young Perennials']
# {'Alfalfa and Alfalfa Mixtures': 2156,
#  'Carrots': 212,
#  'Citrus': 215,
#  'Cole Crops': 277,
#  'Corn, Sorghum and Sudan': 232,
#  'Dates': 34,
#  'Flowers, Nursery and Christmas Tree Farms': 10,
#  'Greenhouse': 12,
#  'Idle': 865,
#  'Lettuce/Leafy Greens': 619,
#  'Managed Wetland': 22,
#  'Melons, Squash and Cucumbers': 153,
#  'Miscellaneous Deciduous': 2,
#  'Miscellaneous Field Crops': 187,
#  'Miscellaneous Grain and Hay': 59,
#  'Miscellaneous Grasses': 1126,
#  'Miscellaneous Subtropical Fruits': 11,
#  'Miscellaneous Truck Crops': 314,
#  'Mixed Pasture': 24,
#  'Olives': 11,
#  'Onions and Garlic': 229,
#  'Peppers': 4,
#  'Potatoes and Sweet Potatoes': 42,
#  'Sunflowers': 5,
#  'Tomatoes': 2,
#  'Urban': 84,
#  'Wheat': 315,
#  'Young Perennials': 44}

# %% [markdown]
# ## Splitting data and making image

# %%
imperial_data = data.randomColumn('random', 2016)
training = imperial_data.filter(ee.Filter.lt('random', 0.6));
validation = imperial_data.filter(ee.Filter.And(
                      ee.Filter.gte('random', 0.6), 
                      ee.Filter.lt('random', 0.8)));
testing = imperial_data.filter(ee.Filter.gte('random', 0.8));
print(training.size().getInfo(), validation.size().getInfo(), testing.size().getInfo())

training_label = training.reduceToImage(
    properties =  ['landover'],
    reducer = ee.Reducer.first()
)
val_label = validation.reduceToImage(
    properties =  ['landover'],
    reducer = ee.Reducer.first()
)
testing_label = testing.reduceToImage(
    properties =  ['landover'],
    reducer = ee.Reducer.first()
)
# Out:
# 4373 1395 1498

# %%
Map.addLayer(training_label, {'palette': 'FF0000'}, 'Training')
Map.addLayer(val_label, {'palette': '0000FF'}, 'validation')
Map.addLayer(testing_label, {'palette': '0000FF'}, 'Testing')
Map.centerObject(training, 10)
Map
# Out:
# Map(bottom=105919.0, center=[32.93580026550981, -115.5107517261226], controls=(WidgetControl(options=['positio…

# %%
label = imperial_data.reduceToImage(
    properties =  ['landover'],
    reducer = ee.Reducer.first()
)
label = label.select('first').rename('landcover')

# %% [markdown]
# ## Making final Image

# %%
kernel_size = 3
image = finalImage.addBands(label).toFloat()

neighbourhood_image = image.neighborhoodToArray(ee.Kernel.rectangle(kernel_size, kernel_size, 'pixels'))
Map.addLayer(neighbourhood_image, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}, 's2_extended')
Map.centerObject(imperial)
Map
# Out:
# Map(bottom=105919.0, center=[32.93979228798953, -115.5223403258469], controls=(WidgetControl(options=['positio…

# %%
neighbourhood_image.bandNames().getInfo()
# Out:
# ['B2',
#  'B3',
#  'B4',
#  'B8',
#  'B11',
#  'B12',
#  'NDVI',
#  'GNDVI',
#  'EVI',
#  'SAVI',
#  'BSI',
#  'NDWI',
#  'NDBI',
#  'B2_1',
#  'B3_1',
#  'B4_1',
#  'B8_1',
#  'B11_1',
#  'B12_1',
#  'NDVI_1',
#  'GNDVI_1',
#  'EVI_1',
#  'SAVI_1',
#  'BSI_1',
#  'NDWI_1',
#  'NDBI_1',
#  'B2_2',
#  'B3_2',
#  'B4_2',
#  'B8_2',
#  'B11_2',
#  'B12_2',
#  'NDVI_2',
#  'GNDVI_2',
#  'EVI_2',
#  'SAVI_2',
#  'BSI_2',
#  'NDWI_2',
#  'NDBI_2',
#  'B2_3',
#  'B3_3',
#  'B4_3',
#  'B8_3',
#  'B11_3',
#  'B12_3',
#  'NDVI_3',
#  'GNDVI_3',
#  'EVI_3',
#  'SAVI_3',
#  'BSI_3',
#  'NDWI_3',
#  'NDBI_3',
#  'B2_4',
#  'B3_4',
#  'B4_4',
#  'B8_4',
#  'B11_4',
#  'B12_4',
#  'NDVI_4',
#  'GNDVI_4',
#  'EVI_4',
#  'SAVI_4',
#  'BSI_4',
#  'NDWI_4',
#  'NDBI_4',
#  'B2_5',
#  'B3_5',
#  'B4_5',
#  'B8_5',
#  'B11_5',
#  'B12_5',
#  'NDVI_5',
#  'GNDVI_5',
#  'EVI_5',
#  'SAVI_5',
#  'BSI_5',
#  'NDWI_5',
#  'NDBI_5',
#  'B2_6',
#  'B3_6',
#  'B4_6',
#  'B8_6',
#  'B11_6',
#  'B12_6',
#  'NDVI_6',
#  'GNDVI_6',
#  'EVI_6',
#  'SAVI_6',
#  'BSI_6',
#  'NDWI_6',
#  'NDBI_6',
#  'B2_7',
#  'B3_7',
#  'B4_7',
#  'B8_7',
#  'B11_7',
#  'B12_7',
#  'NDVI_7',
#  'GNDVI_7',
#  'EVI_7',
#  'SAVI_7',
#  'BSI_7',
#  'NDWI_7',
#  'NDBI_7',
#  'B2_8',
#  'B3_8',
#  'B4_8',
#  'B8_8',
#  'B11_8',
#  'B12_8',
#  'NDVI_8',
#  'GNDVI_8',
#  'EVI_8',
#  'SAVI_8',
#  'BSI_8',
#  'NDWI_8',
#  'NDBI_8',
#  'B2_9',
#  'B3_9',
#  'B4_9',
#  'B8_9',
#  'B11_9',
#  'B12_9',
#  'NDVI_9',
#  'GNDVI_9',
#  'EVI_9',
#  'SAVI_9',
#  'BSI_9',
#  'NDWI_9',
#  'NDBI_9',
#  'B2_10',
#  'B3_10',
#  'B4_10',
#  'B8_10',
#  'B11_10',
#  'B12_10',
#  'NDVI_10',
#  'GNDVI_10',
#  'EVI_10',
#  'SAVI_10',
#  'BSI_10',
#  'NDWI_10',
#  'NDBI_10',
#  'B2_11',
#  'B3_11',
#  'B4_11',
#  'B8_11',
#  'B11_11',
#  'B12_11',
#  'NDVI_11',
#  'GNDVI_11',
#  'EVI_11',
#  'SAVI_11',
#  'BSI_11',
#  'NDWI_11',
#  'NDBI_11',
#  'landcover']

# %% [markdown]
# # Sampling

# %%
# sampling only points for now
training_points = image.select('landcover')\
          .sampleRegions(
            collection= training,
            scale=80,
            tileScale =1,
            properties= ['landcover'],
            geometries = True
          )
val_points = image.select('landcover')\
          .sampleRegions(
            collection= validation,
            scale=80,
            tileScale = 1,
            properties= ['landcover'],
            geometries = True
          )

testing_points = image.select('landcover')\
          .sampleRegions(
            collection= testing,
            scale=80,
            tileScale = 1,
            properties= ['landcover'],
            geometries = True
          )

# %%
# get lat longs of sampled points
training_pts = training_points.geometry().getInfo()['coordinates']
val_pts = val_points.geometry().getInfo()['coordinates']
testing_pts = testing_points.geometry().getInfo()['coordinates']

# %%
testing_points.first().getInfo()
# Out:
# {'type': 'Feature',
#  'geometry': {'geodesic': False,
#   'type': 'Point',
#   'coordinates': [-115.73067670534525, 33.08279595744009]},
#  'id': '00000000000000001073_0',
#  'properties': {}}

# %%
len(training_pts), len(val_pts), len(testing_pts)
# Out:
# (209767, 64907, 70157)

# %%
patch2 = ee.Geometry.Polygon([[-115.58345059458601,32.73187233683694],
    [-115.3465578943907,32.73187233683694],
    [-115.3465578943907,32.943604017691634],
    [-115.58345059458601,32.943604017691634],
    [-115.58345059458601,32.73187233683694]])

# %%
Task = ee.batch.Export.image.toDrive(
    image = image.clip(patch2),
    description = 'patch of imperial',
    folder = 'Imperial_2016_patch',
    fileNamePrefix = 'Imperial_2016_patch3',
    scale = 10,
    fileFormat = 'GeoTIFF',
    region = patch2
)
Task.start()

# %%
# testing_features = testing.toList(1498)
# for i in range(1498):
#     feature = ee.Feature(testing_features.get(i))
#     fcp = testing_points.filterBounds(feature.geometry())
#     train_db = neighbourhood_image.sampleRegions(collection=fcp, scale=10)
#     Task = ee.batch.Export.table.toDrive(
#         collection=train_db,        
#         description="testing_imperial_2016"+str(i),
#         fileNamePrefix="testing_imperial_2016_"+str(i),
#         folder = "testing_polygons_imperial_2016",  
#         fileFormat='TFRecord')
#     Task.start()
#     print(i)

# %%
# val_features = validation.toList(1395)
# for i in range(1395):
#     feature = ee.Feature(val_features.get(i))
#     fcp = val_points.filterBounds(feature.geometry())
#     train_db = neighbourhood_image.sampleRegions(collection=fcp, scale=10)
#     Task = ee.batch.Export.table.toDrive(
#         collection=train_db,        
#         description="validation_imperial_2016"+str(i),
#         fileNamePrefix="validation_imperial_2016_"+str(i),
#         folder = "validation_polygons_imperial_2016",  
#         fileFormat='TFRecord')
#     Task.start()
#     print(i)

# %%
filenames = []
nbands = 12*13+1
nfeatures = 7*7*13*70157 #estimate the totals # of features

nparts = int(np.ceil(nfeatures/1e3))
print('Dataset too long, splitting it into '+ str(nparts),'equal parts.')


nppoints = np.array(testing_pts)
np.random.shuffle(nppoints)

count_batch = 1  # Batch counter 

for batch_arr in np.array_split(nppoints,nparts):

    fcp = ee.FeatureCollection([ee.Feature(ee.Geometry.Point(p),{'class':'NA'}) for p in batch_arr.tolist()])

    train_db = neighbourhood_image.sampleRegions(collection=fcp, scale=30, geometries = True)
    print(train_db.first().getInfo())
    
#     filename = file_name_prefix + str(count_batch)
#     print('sending the task #%04d'%count_batch)
#     Task = ee.batch.Export.table.toDrive(
#             collection=train_db,        
#             description=file_name_prefix+str(count_batch),
#             fileNamePrefix=filename,
#             folder = folder_name,  
#             fileFormat='TFRecord')

#     Task.start()
    break
    filenames.append(filename)
    count_batch+=1
# Out:
# Dataset too long, splitting it into 44691 equal parts.
# {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [-115.72784701220029, 32.81110049975814]}, 'id': '0_0', 'properties': {'B11': [[1832, 1852, 1768, 1723, 1662, 1992, 2503], [2076, 2182, 2101, 2011, 1835, 2153, 2638], [2778, 2763, 2744, 2664, 2467, 2609, 2705], [3123, 3120, 3073, 3084, 3074, 3069, 2958], [3045, 3009, 3025, 3039, 2980, 3056, 2888], [3052, 3016, 3021, 2903, 3017, 3149, 2783], [3109, 3098, 3054, 3017, 3081, 3107, 2788]], 'B11_1': [[1364.5, 1384, 1334.5, 1301.5, 1282.5, 1728.5, 2506], [1451, 1503, 1506.5, 1463.5, 1388, 1907.5, 2631.5], [1995, 2076, 2092, 2017, 2018, 2418.5, 2785.5], [1649, 1661, 1666, 1724, 2102.5, 2826, 3064], [1498, 1495.5, 1496, 1511, 1741, 2592, 2954.5], [1504.5, 1502.5, 1507, 1503.5, 1702.5, 2562.5, 2884.5], [1529.5, 1529.5, 1524, 1525.5, 1724, 2546.5, 2857.5]], 'B11_10': [[1356, 1346, 1334, 1299, 1263, 1850, 2494], [1500, 1497, 1511, 1487, 1459, 2091, 2564], [2175, 2198, 2211, 2118, 2166, 2602, 2698], [1248, 1315, 1361, 1320, 2070, 3073, 2882], [1163, 1115, 1105, 1145, 1744, 2873, 2691], [1128, 1116, 1113, 1137, 1699, 2723, 2537], [1128, 1130, 1126, 1151, 1696, 2673, 2426]], 'B11_11': [[2712, 2761, 2759, 2653, 2596, 2700, 2799], [2654, 2747, 2766, 2664, 2591, 2712, 2841], [2639, 2753, 2803, 2753, 2834, 3010, 2977], [1099, 1120, 1203, 1217, 1840, 3129, 3259], [938, 954, 918, 925, 1518, 2775, 3118], [947, 960, 942, 944, 1434, 2676, 2898], [941, 947, 944, 959, 1357, 2690, 2751]], 'B11_2': [[3342, 3433, 3726, 3699, 3551, 3472, 3046], [3279, 3439, 3699, 3716, 3558, 3417, 3089], [3468, 3614, 3794, 3780, 3647, 3533, 3186], [3273, 3321, 3283, 3226, 3262, 3538, 3484], [3121, 3141, 3140, 3123, 3115, 3307, 3291], [3081, 3076, 3086, 3091, 3144, 3250, 3168], [3099, 3086, 3082, 3062, 3135, 3269, 3078]], 'B11_3': [[4122, 4132, 4142, 4122, 3968, 3723, 3261], [4092, 4097, 4132, 4107, 3966, 3791, 3207], [4098, 4090, 4151, 4128, 4026, 3810, 3266], [3993, 3898, 3874, 3899, 3909, 3851, 3513], [4040, 3900, 3823, 3832, 3889, 3829, 3497], [3953, 4006, 3993, 3964, 3944, 3924, 3456], [3963, 3990, 3987, 3968, 3928, 3912, 3412]], 'B11_4': [[2180.5, 2224.5, 2240, 2205.5, 2084.5, 2522.5, 3157], [2213.5, 2314.5, 2574.5, 2528.5, 2269.5, 2740, 3235.5], [3088, 3128.5, 3401, 3444.5, 3182, 3353, 3391], [2182, 2280.5, 2309.5, 2408.5, 2991.5, 3719.5, 3655.5], [1869, 1953.5, 1966, 2007, 2363, 3212.5, 3488], [1808, 1840.5, 1857, 1873.5, 2036.5, 2906.5, 3353], [1805.5, 1811, 1827, 1855, 2020.5, 2903.5, 3347]], 'B11_5': [[1680, 1662, 1627, 1619, 1636, 2140, 2992], [1751, 1702, 1717, 1674, 1783, 2328, 3058], [2386, 2386, 2593, 2672, 2470, 3093, 3180], [1980, 1967, 2000, 2021, 2338, 3312, 3634], [1657, 1744, 1716, 1693, 1941, 2837, 3468], [1594, 1615, 1621, 1624, 1741, 2663, 3245], [1607, 1606, 1614, 1631, 1766, 2651, 3206]], 'B11_6': [[4737, 4742, 4751, 4755, 4644, 4256, 3515], [4621, 4649, 4694, 4668, 4557, 4258, 3495], [4542, 4547, 4565, 4561, 4505, 4310, 3576], [4665, 4601, 4586, 4572, 4587, 4420, 3915], [4612, 4626, 4633, 4632, 4570, 4278, 3737], [4632, 4659, 4701, 4710, 4623, 4335, 3658], [4618, 4649, 4663, 4682, 4604, 4353, 3615]], 'B11_7': [[3254, 3244, 3207, 3189, 3164, 3238, 3239], [3285, 3276, 3246, 3222, 3217, 3315, 3241], [3526, 3492, 3480, 3483, 3467, 3511, 3366], [4327, 4340, 4349, 4327, 4320, 4208, 3793], [4338, 4338, 4354, 4328, 4304, 4162, 3684], [4349, 4346, 4342, 4339, 4322, 4239, 3626], [4362, 4342, 4342, 4335, 4319, 4235, 3577]], 'B11_8': [[2732.5, 2726, 2694.5, 2682.5, 2706, 2713.5, 2834], [2728.5, 2788, 2724, 2684, 2703, 2712, 2886.5], [2980, 2942, 2926.5, 2953.5, 2821.5, 2815, 2973], [3007.5, 2999.5, 2965.5, 2976.5, 3126, 3386.5, 3523], [2831.5, 2790, 2809, 2807.5, 2883, 3202.5, 3383.5], [2853, 2792, 2773, 2763, 2798.5, 3130, 3218.5], [2865, 2803, 2776.5, 2755, 2800, 3094.5, 3186]], 'B11_9': [[3177.5, 3151.5, 3056, 2938, 2831.5, 3017, 3021.5], [3197, 3169, 3146, 3068, 2938.5, 3139.5, 3096.5], [3401.5, 3350.5, 3324, 3305.5, 3194.5, 3329, 3191.5], [3106.5, 3068.5, 2914, 2795, 266 ...

# %% [markdown]
# # EXPORT

# %%
def export_2D_samples(collection, num_of_images, num_features, dimension, file_name_prefix, folder_name):
    filenames = []
    nbands = num_of_images*num_features+1
    nfeatures = dimension*dimension*nbands*len(collection) #estimate the totals # of features

    nparts = int(np.ceil(nfeatures/3e6))
    print('Dataset too long, splitting it into '+ str(nparts),'equal parts.')


    nppoints = np.array(collection)
    np.random.shuffle(nppoints)

    count_batch = 1  # Batch counter 

    for batch_arr in np.array_split(nppoints,nparts):

        fcp = ee.FeatureCollection([ee.Feature(ee.Geometry.Point(p),{'class':'NA'}) for p in batch_arr.tolist()])

        train_db = neighbourhood_image.sampleRegions(collection=fcp, scale=10, geometries = True)

        filename = file_name_prefix + str(count_batch)
        print('sending the task #%04d'%count_batch)
        Task = ee.batch.Export.table.toDrive(
                collection=train_db,        
                description=file_name_prefix+str(count_batch),
                fileNamePrefix=filename,
                folder = folder_name,  
                fileFormat='TFRecord')

        Task.start()
        filenames.append(filename)
        count_batch+=1

# %%
export_2D_samples(collection = training_pts, 
                  num_of_images = 12, 
                  num_features = 13, 
                  dimension = 7, 
                  file_name_prefix = "training_imperial_2016_", 
                  folder_name = "training_imperial_2016_28c")
# Out:
# Dataset too long, splitting it into 538 equal parts.
# sending the task #0001
# sending the task #0002
# sending the task #0003
# sending the task #0004
# sending the task #0005
# sending the task #0006
# sending the task #0007
# sending the task #0008
# sending the task #0009
# sending the task #0010
# sending the task #0011
# sending the task #0012
# sending the task #0013
# sending the task #0014
# sending the task #0015
# sending the task #0016
# sending the task #0017
# sending the task #0018
# sending the task #0019
# sending the task #0020
# sending the task #0021
# sending the task #0022
# sending the task #0023
# sending the task #0024
# sending the task #0025
# sending the task #0026
# sending the task #0027
# sending the task #0028
# sending the task #0029
# sending the task #0030
# sending the task #0031
# sending the task #0032
# sending the task #0033
# sending the task #0034
# sending the task #0035
# sending the task #0036
# sending the task #0037
# sending the task #0038
# sending the task #0039
# sending the task #0040
# sending the task #0041
# sending the task #0042
# sending the task #0043
# sending the task #0044
# sending the task #0045
# sending the task #0046
# sending the task #0047
# sending the task #0048
# sending the task #0049
# sending the task #0050
# sending the task #0051
# sending the task #0052
# sending the task #0053
# sending the task #0054
# sending the task #0055
# sending the task #0056
# sending the task #0057
# sending the task #0058
# sending the task #0059
# sending the task #0060
# sending the task #0061
# sending the task #0062
# sending the task #0063
# sending the task #0064
# sending the task #0065
# sending the task #0066
# sending the task #0067
# sending the task #0068
# sending the task #0069
# sending the task #0070
# sending the task #0071
# sending the task #0072
# sending the task #0073
# sending the task #0074
# sending the task #0075
# sending the task #0076
# sending the task #0077
# sending the task #0078
# sending the task #0079
# sending the task #0080
# sending the task #0081
# sending the task #0082
# sending the task #0083
# sending the task #0084
# sending the task #0085
# sending the task #0086
# sending the task #0087
# sending the task #0088
# sending the task #0089
# sending the task #0090
# sending the task #0091
# sending the task #0092
# sending the task #0093
# sending the task #0094
# sending the task #0095
# sending the task #0096
# sending the task #0097
# sending the task #0098
# sending the task #0099
# sending the task #0100
# sending the task #0101
# sending the task #0102
# sending the task #0103
# sending the task #0104
# sending the task #0105
# sending the task #0106
# sending the task #0107
# sending the task #0108
# sending the task #0109
# sending the task #0110
# sending the task #0111
# sending the task #0112
# sending the task #0113
# sending the task #0114
# sending the task #0115
# sending the task #0116
# sending the task #0117
# sending the task #0118
# sending the task #0119
# sending the task #0120
# sending the task #0121
# sending the task #0122
# sending the task #0123
# sending the task #0124
# sending the task #0125
# sending the task #0126
# sending the task #0127
# sending the task #0128
# sending the task #0129
# sending the task #0130
# sending the task #0131
# sending the task #0132
# sending the task #0133
# sending the task #0134
# sending the task #0135
# sending the task #0136
# sending the task #0137
# sending the task #0138
# sending the task #0139
# sending the task #0140
# sending the task #0141
# sending the task #0142
# sending the task #0143
# sending the task #0144
# sending the task #0145
# sending the task #0146
# sending the task #0147
# sending the task #0148
# sending the task #0149
# sending the task #0150
# sending the task #0151
# sending the task #0152
# sending the task #0153
# sending the task #0154
# sending the task #0155
# sending the task #0156
# sending the task #0157
# sending the task #0158
# sending the task #0159
# sending the task #0160
# sending the task #0161
# sending the task #0162
# sending the task #0163
# sending the task #0164
# sending the task #0165
# sending the task #0166
# sending the task #0167
# sending the task #0168
# sending the task #0169
# sending the task #0170
# sending the task #0171
# sending the task #0172
# sending the task #0173
# sending the task #0174
# sending the task #0175
# sending the task #0176
# sending the task #0177
# sending the task #0178
# sending the task #0179
# sending the task #0180
# sending the task #0181
# sending the task #0182
# sending the task #0183
# sending the task #0184
# sending the task #0185
# sending the task #0186
# sending the task #0187
# sending the task #0188
# sending the task #0189
# sending the task #0190
# sending the task #0191
# sending the task #0192
# sending the task #0193
# sending the task #0194
# sending the task #0195
# sending the task #0196
# sending the task #0197
# sending the task #0198
# sending the task #0199
# sending the task #0200
# sending the task #0201
# sending the task #0202
# sending the task #0203
# sending the task #0204
# sending the task #0205
# sending the task #0206
# sending the task #0207
# sending the task #0208
# sending the task #0209
# sending the task #0210
# sending the task #0211
# sending the task #0212
# sending the task #0213
# sending the task #0214
# sending the task #0215
# sending the task #0216
# sending the task #0217
# sending the task #0218
# sending the task #0219
# sending the task #0220
# sending the task #0221
# sending the task #0222
# sending the task #0223
# sending the task #0224
# sending the task #0225
# sending the task #0226
# sending the task #0227
# sending the task #0228
# sending the task #0229
# sending the task #0230
# sending the task #0231
# sending the task #0232
# sending the task #0233
# sending the task #0234
# sending the task #0235
# sending the task #0236
# sending the task #0237
# sending the task #0238
# sending the task #0239
# sending the task #0240
# sending the task #0241
# sending the task #0242
# sending the task #0243
# sending the task #0244
# sending the task #0245
# sending the task #0246
# sending the task #0247
# sending the task #0248
# sending the task #0249
# sending the task #0250
# sending the task #0251
# sending the task #0252
# sending the task #0253
# sending the task #0254
# sending the task #0255
# sending the task #0256
# sending the task #0257
# sending the task #0258
# sending the task #0259
# sending the task #0260
# sending the task #0261
# sending the task #0262
# sending the task #0263
# sending the task #0264
# sending the task #0265
# sending the task #0266
# sending the task #0267
# sending the task #0268
# sending the task #0269
# sending the task #0270
# sending the task #0271
# sending the task #0272
# sending the task #0273
# sending the task #0274
# sending the task #0275
# sending the task #0276
# sending the task #0277
# sending the task #0278
# sending the task #0279
# sending the task #0280
# sending the task #0281
# sending the task #0282
# sending the task #0283
# sending the task #0284
# sending the task #0285
# sending the task #0286
# sending the task #0287
# sending the task #0288
# sending the task #0289
# sending the task #0290
# sending the task #0291
# sending the task #0292
# sending the task #0293
# sending the task #0294
# sending the task #0295
# sending the task #0296
# sending the task #0297
# sending the task #0298
# sending the task #0299
# sending the task #0300
# sending the task #0301
# sending the task #0302
# sending the task #0303
# sending the task #0304
# sending the task #0305
# sending the task #0306
# sending the task #0307
# sending the task #0308
# sending the task #0309
# sending the task #0310
# sending the task #0311
# sending the task #0312
# sending the task #0313
# sending the task #0314
# sending the task #0315
# sending the task #0316
# sending the task #0317
# sending the task #0318
# sending the task #0319
# sending the task #0320
# sending the task #0321
# sending the task #0322
# sending the task #0323
# sending the task #0324
# sending the task #0325
# sending the task #0326
# sending the task #0327
# sending the task #0328
# sending the task #0329
# sending the task #0330
# sending the task #0331
# sending the task #0332
# sending the task #0333
# sending the task #0334
# sending the task #0335
# sending the task #0336
# sending the task #0337
# sending the task #0338
# sending the task #0339
# sending the task #0340
# sending the task #0341
# sending the task #0342
# sending the task #0343
# sending the task #0344
# sending the task #0345
# sending the task #0346
# sending the task #0347
# sending the task #0348
# sending the task #0349
# sending the task #0350
# sending the task #0351
# sending the task #0352
# sending the task #0353
# sending the task #0354
# sending the task #0355
# sending the task #0356
# sending the task #0357
# sending the task #0358
# sending the task #0359
# sending the task #0360
# sending the task #0361
# sending the task #0362
# sending the task #0363
# sending the task #0364
# sending the task #0365
# sending the task #0366
# sending the task #0367
# sending the task #0368
# sending the task #0369
# sending the task #0370
# sending the task #0371
# sending the task #0372
# sending the task #0373
# sending the task #0374
# sending the task #0375
# sending the task #0376
# sending the task #0377
# sending the task #0378
# sending the task #0379
# sending the task #0380
# sending the task #0381
# sending the task #0382
# sending the task #0383
# sending the task #0384
# sending the task #0385
# sending the task #0386
# sending the task #0387
# sending the task #0388
# sending the task #0389
# sending the task #0390
# sending the task #0391
# sending the task #0392
# sending the task #0393
# sending the task #0394
# sending the task #0395
# sending the task #0396
# sending the task #0397
# sending the task #0398
# sending the task #0399
# sending the task #0400
# sending the task #0401
# sending the task #0402
# sending the task #0403
# sending the task #0404
# sending the task #0405
# sending the task #0406
# sending the task #0407
# sending the task #0408
# sending the task #0409
# sending the task #0410
# sending the task #0411
# sending the task #0412
# sending the task #0413
# sending the task #0414
# sending the task #0415
# sending the task #0416
# sending the task #0417
# sending the task #0418
# sending the task #0419
# sending the task #0420
# sending the task #0421
# sending the task #0422
# sending the task #0423
# sending the task #0424
# sending the task #0425
# sending the task #0426
# sending the task #0427
# sending the task #0428
# sending the task #0429
# sending the task #0430
# sending the task #0431
# sending the task #0432
# sending the task #0433
# sending the task #0434
# sending the task #0435
# sending the task #0436
# sending the task #0437
# sending the task #0438
# sending the task #0439
# sending the task #0440
# sending the task #0441
# sending the task #0442
# sending the task #0443
# sending the task #0444
# sending the task #0445
# sending the task #0446
# sending the task #0447
# sending the task #0448
# sending the task #0449
# sending the task #0450
# sending the task #0451
# sending the task #0452
# sending the task #0453
# sending the task #0454
# sending the task #0455
# sending the task #0456
# sending the task #0457
# sending the task #0458
# sending the task #0459
# sending the task #0460
# sending the task #0461
# sending the task #0462
# sending the task #0463
# sending the task #0464
# sending the task #0465
# sending the task #0466
# sending the task #0467
# sending the task #0468
# sending the task #0469
# sending the task #0470
# sending the task #0471
# sending the task #0472
# sending the task #0473
# sending the task #0474
# sending the task #0475
# sending the task #0476
# sending the task #0477
# sending the task #0478
# sending the task #0479
# sending the task #0480
# sending the task #0481
# sending the task #0482
# sending the task #0483
# sending the task #0484
# sending the task #0485
# sending the task #0486
# sending the task #0487
# sending the task #0488
# sending the task #0489
# sending the task #0490
# sending the task #0491
# sending the task #0492
# sending the task #0493
# sending the task #0494
# sending the task #0495
# sending the task #0496
# sending the task #0497
# sending the task #0498
# sending the task #0499
# sending the task #0500
# sending the task #0501
# sending the task #0502
# sending the task #0503
# sending the task #0504
# sending the task #0505
# sending the task #0506
# sending the task #0507
# sending the task #0508
# sending the task #0509
# sending the task #0510
# sending the task #0511
# sending the task #0512
# sending the task #0513
# sending the task #0514
# sending the task #0515
# sending the task #0516
# sending the task #0517
# sending the task #0518
# sending the task #0519
# sending the task #0520
# sending the task #0521
# sending the task #0522
# sending the task #0523
# sending the task #0524
# sending the task #0525
# sending the task #0526
# sending the task #0527
# sending the task #0528
# sending the task #0529
# sending the task #0530
# sending the task #0531
# sending the task #0532
# sending the task #0533
# sending the task #0534
# sending the task #0535
# sending the task #0536
# sending the task #0537
# sending the task #0538

# %%
export_2D_samples(collection = val_pts, 
                  num_of_images = 12, 
                  num_features = 13, 
                  dimension = 7, 
                  file_name_prefix = "validation_imperial_2016_", 
                  folder_name = "validation_imperial_2016_28c")
# Out:
# Dataset too long, splitting it into 167 equal parts.
# sending the task #0001
# sending the task #0002
# sending the task #0003
# sending the task #0004
# sending the task #0005
# sending the task #0006
# sending the task #0007
# sending the task #0008
# sending the task #0009
# sending the task #0010
# sending the task #0011
# sending the task #0012
# sending the task #0013
# sending the task #0014
# sending the task #0015
# sending the task #0016
# sending the task #0017
# sending the task #0018
# sending the task #0019
# sending the task #0020
# sending the task #0021
# sending the task #0022
# sending the task #0023
# sending the task #0024
# sending the task #0025
# sending the task #0026
# sending the task #0027
# sending the task #0028
# sending the task #0029
# sending the task #0030
# sending the task #0031
# sending the task #0032
# sending the task #0033
# sending the task #0034
# sending the task #0035
# sending the task #0036
# sending the task #0037
# sending the task #0038
# sending the task #0039
# sending the task #0040
# sending the task #0041
# sending the task #0042
# sending the task #0043
# sending the task #0044
# sending the task #0045
# sending the task #0046
# sending the task #0047
# sending the task #0048
# sending the task #0049
# sending the task #0050
# sending the task #0051
# sending the task #0052
# sending the task #0053
# sending the task #0054
# sending the task #0055
# sending the task #0056
# sending the task #0057
# sending the task #0058
# sending the task #0059
# sending the task #0060
# sending the task #0061
# sending the task #0062
# sending the task #0063
# sending the task #0064
# sending the task #0065
# sending the task #0066
# sending the task #0067
# sending the task #0068
# sending the task #0069
# sending the task #0070
# sending the task #0071
# sending the task #0072
# sending the task #0073
# sending the task #0074
# sending the task #0075
# sending the task #0076
# sending the task #0077
# sending the task #0078
# sending the task #0079
# sending the task #0080
# sending the task #0081
# sending the task #0082
# sending the task #0083
# sending the task #0084
# sending the task #0085
# sending the task #0086
# sending the task #0087
# sending the task #0088
# sending the task #0089
# sending the task #0090
# sending the task #0091
# sending the task #0092
# sending the task #0093
# sending the task #0094
# sending the task #0095
# sending the task #0096
# sending the task #0097
# sending the task #0098
# sending the task #0099
# sending the task #0100
# sending the task #0101
# sending the task #0102
# sending the task #0103
# sending the task #0104
# sending the task #0105
# sending the task #0106
# sending the task #0107
# sending the task #0108
# sending the task #0109
# sending the task #0110
# sending the task #0111
# sending the task #0112
# sending the task #0113
# sending the task #0114
# sending the task #0115
# sending the task #0116
# sending the task #0117
# sending the task #0118
# sending the task #0119
# sending the task #0120
# sending the task #0121
# sending the task #0122
# sending the task #0123
# sending the task #0124
# sending the task #0125
# sending the task #0126
# sending the task #0127
# sending the task #0128
# sending the task #0129
# sending the task #0130
# sending the task #0131
# sending the task #0132
# sending the task #0133
# sending the task #0134
# sending the task #0135
# sending the task #0136
# sending the task #0137
# sending the task #0138
# sending the task #0139
# sending the task #0140
# sending the task #0141
# sending the task #0142
# sending the task #0143
# sending the task #0144
# sending the task #0145
# sending the task #0146
# sending the task #0147
# sending the task #0148
# sending the task #0149
# sending the task #0150
# sending the task #0151
# sending the task #0152
# sending the task #0153
# sending the task #0154
# sending the task #0155
# sending the task #0156
# sending the task #0157
# sending the task #0158
# sending the task #0159
# sending the task #0160
# sending the task #0161
# sending the task #0162
# sending the task #0163
# sending the task #0164
# sending the task #0165
# sending the task #0166
# sending the task #0167

# %%
export_2D_samples(collection = testing_pts, 
                  num_of_images = 12, 
                  num_features = 13, 
                  dimension = 7, 
                  file_name_prefix = "testing_imperial_2016_", 
                  folder_name = "testing_imperial_2016_28c")
# Out:
# Dataset too long, splitting it into 180 equal parts.
# sending the task #0001
# sending the task #0002
# sending the task #0003
# sending the task #0004
# sending the task #0005
# sending the task #0006
# sending the task #0007
# sending the task #0008
# sending the task #0009
# sending the task #0010
# sending the task #0011
# sending the task #0012
# sending the task #0013
# sending the task #0014
# sending the task #0015
# sending the task #0016
# sending the task #0017
# sending the task #0018
# sending the task #0019
# sending the task #0020
# sending the task #0021
# sending the task #0022
# sending the task #0023
# sending the task #0024
# sending the task #0025
# sending the task #0026
# sending the task #0027
# sending the task #0028
# sending the task #0029
# sending the task #0030
# sending the task #0031
# sending the task #0032
# sending the task #0033
# sending the task #0034
# sending the task #0035
# sending the task #0036
# sending the task #0037
# sending the task #0038
# sending the task #0039
# sending the task #0040
# sending the task #0041
# sending the task #0042
# sending the task #0043
# sending the task #0044
# sending the task #0045
# sending the task #0046
# sending the task #0047
# sending the task #0048
# sending the task #0049
# sending the task #0050
# sending the task #0051
# sending the task #0052
# sending the task #0053
# sending the task #0054
# sending the task #0055
# sending the task #0056
# sending the task #0057
# sending the task #0058
# sending the task #0059
# sending the task #0060
# sending the task #0061
# sending the task #0062
# sending the task #0063
# sending the task #0064
# sending the task #0065
# sending the task #0066
# sending the task #0067
# sending the task #0068
# sending the task #0069
# sending the task #0070
# sending the task #0071
# sending the task #0072
# sending the task #0073
# sending the task #0074
# sending the task #0075
# sending the task #0076
# sending the task #0077
# sending the task #0078
# sending the task #0079
# sending the task #0080
# sending the task #0081
# sending the task #0082
# sending the task #0083
# sending the task #0084
# sending the task #0085
# sending the task #0086
# sending the task #0087
# sending the task #0088
# sending the task #0089
# sending the task #0090
# sending the task #0091
# sending the task #0092
# sending the task #0093
# sending the task #0094
# sending the task #0095
# sending the task #0096
# sending the task #0097
# sending the task #0098
# sending the task #0099
# sending the task #0100
# sending the task #0101
# sending the task #0102
# sending the task #0103
# sending the task #0104
# sending the task #0105
# sending the task #0106
# sending the task #0107
# sending the task #0108
# sending the task #0109
# sending the task #0110
# sending the task #0111
# sending the task #0112
# sending the task #0113
# sending the task #0114
# sending the task #0115
# sending the task #0116
# sending the task #0117
# sending the task #0118
# sending the task #0119
# sending the task #0120
# sending the task #0121
# sending the task #0122
# sending the task #0123
# sending the task #0124
# sending the task #0125
# sending the task #0126
# sending the task #0127
# sending the task #0128
# sending the task #0129
# sending the task #0130
# sending the task #0131
# sending the task #0132
# sending the task #0133
# sending the task #0134
# sending the task #0135
# sending the task #0136
# sending the task #0137
# sending the task #0138
# sending the task #0139
# sending the task #0140
# sending the task #0141
# sending the task #0142
# sending the task #0143
# sending the task #0144
# sending the task #0145
# sending the task #0146
# sending the task #0147
# sending the task #0148
# sending the task #0149
# sending the task #0150
# sending the task #0151
# sending the task #0152
# sending the task #0153
# sending the task #0154
# sending the task #0155
# sending the task #0156
# sending the task #0157
# sending the task #0158
# sending the task #0159
# sending the task #0160
# sending the task #0161
# sending the task #0162
# sending the task #0163
# sending the task #0164
# sending the task #0165
# sending the task #0166
# sending the task #0167
# sending the task #0168
# sending the task #0169
# sending the task #0170
# sending the task #0171
# sending the task #0172
# sending the task #0173
# sending the task #0174
# sending the task #0175
# sending the task #0176
# sending the task #0177
# sending the task #0178
# sending the task #0179
# sending the task #0180
